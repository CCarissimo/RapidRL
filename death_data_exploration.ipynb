# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./death1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  buffer_size  repetition  number_of_deaths  lifetime_average  \
# 0           0          100           0                65        150.876923
# 1           1          100           1                64        148.234375
# 2           2          100           2                67        147.895522
# 3           3          100           3                61        163.426230
# 4           4          100           4                69        144.869565
#
#    lifetime_variance  visits_differences_mean  abs_visits_differences_mean  \
# 0       36491.184852                 0.020972                     1.030833
# 1       23209.491943                 0.001199                     1.011711
# 2       16490.123413                 0.007205                     0.942020
# 3       19385.195378                 0.012296                     1.148000
# 4       19055.359798                 0.003333                     0.973791
#
#    visits_differences_var  n_table_differences_mean  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   buffer_size   repetition  number_of_deaths  \
# count  1240.000000   1240.000000  1240.000000       1240.000000
# mean    619.500000   5050.000000    19.500000         43.890323
# std     358.101475   2952.800616    11.548054          4.292859
# min       0.000000    100.000000     0.000000         39.000000
# 25%     309.750000   2410.000000     9.750000         42.000000
# 50%     619.500000   5050.000000    19.500000         43.000000
# 75%     929.250000   7690.000000    29.250000         44.000000
# max    1239.000000  10000.000000    39.000000         72.000000
#
#        lifetime_average  lifetime_variance  visits_differences_mean  \
# count       1240.000000        1240.000000              1240.000000
# mean         208.236587       93763.059122                 0.103462
# std           17.997139       40081.238613                 0.077340
# min          136.138889       15119.409668                -0.008997
# ...

# %%
sns.lmplot(data=df, x='visits_differences_mean', y='n_table_differences_mean')

# %%
sns.scatterplot(data=df, x='number_of_deaths', y='n_table_differences_mean')
# Out:
# <AxesSubplot: xlabel='number_of_deaths', ylabel='n_table_differences_mean'>

# %%
sns.scatterplot(data=df, x='number_of_deaths', y='lifetime_average')
# Out:
# <AxesSubplot: xlabel='number_of_deaths', ylabel='lifetime_average'>

# %%
sns.pairplot(data=df,corner='corner')

# %%
sns.jointplot(data=df, x='number_of_deaths', y='lifetime_average',kind="hex", color="#4CB391")
